# %% [markdown]
# - title: Job Interview Assistant
#   1. Accept JD text/file & parse for key info
#   2. Auto-generate interview questions
#   3. Voice output for questions
#   4. Convert spoken user replies to text
#   5. Compare response vs. model answer
#   6. Textual insights + scoring
#   7. Voice or Text interview preference
#   8. Save Q&A history, feedback, scores

# %% [markdown]
# Intro Generate Using Lamma

# %%
#   1. Accept JD text/file & parse for key info
#  2. Auto-generate interview questions

Intro = "Hi there my name is jd, i am here to help you ace you next interview, simply provide me with the job description and i will generate a list of interview questions for you to practice with.\n\n"

user_input = input("Please provide the job description: ")

# %%
generate_questions = ""

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# Load tokenizer and model
model_name = "Llama-3.1-8B-Instruct"  # Example: choose the actual LLaMA 3 model you want
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16, device_map="auto")

# Prompt for introduction
prompt = "Write a short and engaging introduction about the importance of artificial intelligence in modern society:\n"

# Tokenize input
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# Generate output
with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=150,
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        repetition_penalty=1.1
    )

# Decode and print result
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(generated_text)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\Dell\anaconda3\envs\dl12\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\Dell\anaconda3\envs\dl12\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...

# %% [markdown]
# - Voice output for questions
#   - Use Kokoro for text to speech generation

# %%
Intro = "Hi there my name is jd, i am here to help you prepare for your next job interview, simply provide me with the job description and i will generate a list of interview questions for you to practice with.\n\n"

# %%
from kokoro import KPipeline
from IPython.display import display, Audio
import soundfile as sf


pipeline = KPipeline(lang_code='a', repo_id='hexgrad/Kokoro-82M')
generator = pipeline(text= Intro, voice='hm_omega') # hm_omega
for i, (gs, ps, audio) in enumerate(generator):
    # print(i, gs, ps)
    print(gs)
    display(Audio(data=audio, rate=24000, autoplay=i==0))
    sf.write(f'tts_reply.wav', audio, 24000)
# Out:
# Hi there my name is jd, i am here to help you prepare for your next job interview, simply provide me with the job description and i will generate a list of interview questions for you to practice with.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# - Convert spoken user replies to text
#   - Whisper

# %%
import whisper 
model = whisper.load_model("base") 

result = model.transcribe("tts_reply.wav") 
print(result["text"])
# Out:
#  Hi there, my name is JD. I am here to help you prepare for your next job interview. Simply provide me with the job description and I will generate a list of interview questions for you to practice with.

# %% [markdown]
# - Compare response vs. model answer

# %% [markdown]
# - Textual insights + scoring

# %% [markdown]
# - Voice or Text interview preference

# %% [markdown]
# - Save Q&A history, feedback, scores
